# %% [markdown]
# <a href="https://colab.research.google.com/github/dodor3030/303030/blob/main/EX02_06_%E9%96%8B%E7%9C%BC%E9%9B%BB%E5%BD%B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

url = 'http://www.atmovies.com.tw/movie/next/'
html = requests.get(url)
html.encoding = 'utf-8'
soup = BeautifulSoup(html.text, 'lxml')
soup.title
# Out:
# <title>開眼電影網首頁--近期上映--</title>

# %%
import os
import csv

if not os.path.exists('/content/movies'):
  os.mkdir('/content/movies')

movies = [['電影','上映日期']]

for mv in soup.find('ul',class_='filmListAllX').find_all('li'):
  ttl = mv.img['alt']
  src = mv.img['src'].strip()
  dat = mv.find('div',class_="runtime").text
  dat = dat[5:15]
  movies.append([ttl,dat])
  print(ttl,dat,src)
  # !wget $src -O /content/movies/{ttl}.jpg{src}
  #response = requests.get(src)
  #with open(f'/content/movies/{ttl}.jpg','wb')as f:
    #f.write(response.content)

with open('/content/movies.csv','w',newline='') as f:
  writer = csv.writer(f)
  writer.writerows(movies)
# Out:
# 我依然在此 2025/04/02 http://www.atmovies.com.tw/photo101/fipt14961016/pl_fipt14961016_0002.jpg
# --2025-03-25 08:30:35--  http://www.atmovies.com.tw/photo101/fipt14961016/pl_fipt14961016_0002.jpg
# Resolving www.atmovies.com.tw (www.atmovies.com.tw)... 61.61.96.231
# Connecting to www.atmovies.com.tw (www.atmovies.com.tw)|61.61.96.231|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 78018 (76K) [image/jpeg]
# Saving to: ‘/content/movies/我依然在此.jpg’
#
# /content/movies/我  100%[===================>]  76.19K  78.1KB/s    in 1.0s
#
# 2025-03-25 08:30:36 (78.1 KB/s) - ‘/content/movies/我依然在此.jpg’ saved [78018/78018]
#
# --2025-03-25 08:30:36--  http://www.atmovies.com.tw/photo101/fipt14961016/pl_fipt14961016_0002.jpg
# Reusing existing connection to www.atmovies.com.tw:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 78018 (76K) [image/jpeg]
# Saving to: ‘/content/movies/我依然在此.jpg’
#
# ...
