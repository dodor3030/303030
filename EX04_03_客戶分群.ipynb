# %% [markdown]
# <a href="https://colab.research.google.com/github/dodor3030/303030/blob/main/EX04_03_%E5%AE%A2%E6%88%B6%E5%88%86%E7%BE%A4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -0 car_models.csv https://raw.githubusercontent.com/imchihchao/aop113b/main/materials/04-customer.csv
# Out:
# wget: invalid option -- '0'
# Usage: wget [OPTION]... [URL]...
#
# Try `wget --help' for more options.

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/imchihchao/aop113b/main/materials/04-customer.csv'
df = pd.read_csv(url)
df.head()
# Out:
#   性別  年齡  收入（千）  消費指數（1~100）
# 0  女  74     38           81
# 1  女  51     71           91
# 2  女  30     65           10
# 3  女  88     49           17
# 4  女  55     48           70

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   性別           200 non-null    object
#  1   年齡           200 non-null    int64
#  2   收入（千）        200 non-null    int64
#  3   消費指數（1~100）  200 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 6.4+ KB

# %%
df_cor = df.drop(columns='性別').corr()
df_cor
# Out:
#                    年齡     收入（千）  消費指數（1~100）
# 年齡           1.000000  0.031519    -0.127454
# 收入（千）        0.031519  1.000000     0.031476
# 消費指數（1~100） -0.127454  0.031476     1.000000

# %%
df['性別'].unique()
# Out:
# array(['女', '男'], dtype=object)

# %%
from sklearn.preprocessing import OrdinalEncoder
encoder = OrdinalEncoder(categories=[['女','男']])
df[['性別']] = encoder.fit_transform(df[['性別']])
df
# Out:
#       性別  年齡  收入（千）  消費指數（1~100）
# 0    0.0  74     38           81
# 1    0.0  51     71           91
# 2    0.0  30     65           10
# 3    0.0  88     49           17
# 4    0.0  55     48           70
# ..   ...  ..    ...          ...
# 195  1.0  86     84           82
# 196  1.0  59     52           30
# 197  0.0  63     29           61
# 198  1.0  67     80            9
# 199  1.0  72     69           92
#
# [200 rows x 4 columns]

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3)
kmeans.fit(df)
# Out:
# KMeans(n_clusters=3)

# %%
df['cluster'] = kmeans.labels_
df
# Out:
#       性別  年齡  收入（千）  消費指數（1~100）  cluster
# 0    0.0  74     38           81        0
# 1    0.0  51     71           91        2
# 2    0.0  30     65           10        1
# 3    0.0  88     49           17        1
# 4    0.0  55     48           70        0
# ..   ...  ..    ...          ...      ...
# 195  1.0  86     84           82        2
# 196  1.0  59     52           30        1
# 197  0.0  63     29           61        0
# 198  1.0  67     80            9        1
# 199  1.0  72     69           92        2
#
# [200 rows x 5 columns]

# %%
df.groupby('cluster').mean()
# Out:
#                性別         年齡      收入（千）  消費指數（1~100）
# cluster
# 0        0.500000  51.426471  39.044118    69.220588
# 1        0.589744  56.910256  61.243590    20.282051
# 2        0.629630  48.629630  80.240741    78.203704

# %%
from sklearn.metrics import calinski_harabasz_score
score = calinski_harabasz_score(df.drop(columns='cluster'), kmeans.labels_)
score
# Out:
# np.float64(97.25281504434099)

# %%
df_nocluster = df.drop(columns='cluster')
for i in range(2,16):
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(df_nocluster)
    score = calinski_harabasz_score(df_nocluster, kmeans.labels_)
    print(f'k={i} score={score}')
# Out:
# k=2 score=111.68453199285265
# k=3 score=88.32760948752541
# k=4 score=91.13246246366955
# k=5 score=87.59619368978613
# k=6 score=84.32257266930748
# k=7 score=81.67101600866671
# k=8 score=100.17554202348705
# k=9 score=94.7390867612684
# k=10 score=96.45894361032302
# k=11 score=93.45319980094938
# k=12 score=89.24129889017654
# k=13 score=83.65342669838611
# k=14 score=84.75266550239799
# k=15 score=85.59739247464631
